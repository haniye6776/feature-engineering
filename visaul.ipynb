# %%
import numpy
import pandas as pd
import seaborn as sbn

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2711a422-1cb3-446b-ad91-e61b836870f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2711a422-1cb3-446b-ad91-e61b836870f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['dataset.csv']))

# %%
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %%
df1=df.sample(1000)
df2=df.sample(2000)
df3=df.sample(3000)

# %%
df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571          6.886980           1.727848     9.899186
# std          0.605747          5.298964           1.313793     4.331792
# min          1.000000          1.000000           0.000000     1.000000
# 25%          1.000000          1.000000           1.000000     6.000000
# 50%          1.000000          8.000000           1.000000    10.000000
# 75%          1.000000         12.000000           2.000000    13.000000
# max          6.000000         18.000000           9.000000    17.000000
#
#        Daytime/evening attendance  Previous qualification  Nacionality  \
# count                 4424.000000             4424.000000  4424.000000
# mean                     0.890823                2.531420     1.254521
# std                      0.311897                3.963707     1.748447
# ...

# %%
df1["GDP"].mean()
# Out:
# -0.004669999999999996

# %%
df2["GDP"].mean()
# Out:
# 0.016880000000000017

# %%
df3["GDP"].mean()
# Out:
# -0.003213333333333329

# %%
df["GDP"].mean()
# Out:
# 0.001968806509945778

# %%
df[df["Target"]=="Dropout"]["Age at enrollment"].median()
# Out:
# 23.0

# %%
dfdrop=df[df["Target"]=="Dropout"]
dfgrad=df[df["Target"]=="Graduate"]

# %%
dfdrop.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     1421.000000       1421.000000        1421.000000  1421.000000
# mean         1.261084          8.342013           1.593244     9.898663
# std          0.721958          4.962662           1.215769     4.678344
# min          1.000000          1.000000           1.000000     1.000000
# 25%          1.000000          4.000000           1.000000     6.000000
# 50%          1.000000          9.000000           1.000000    10.000000
# 75%          1.000000         12.000000           2.000000    14.000000
# max          6.000000         17.000000           6.000000    17.000000
#
#        Daytime/evening attendance  Previous qualification  Nacionality  \
# count                 1421.000000             1421.000000  1421.000000
# mean                     0.854328                3.059113     1.250528
# std                      0.352901                4.294529     1.790981
# ...

# %%
dfgrad.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     2209.000000       2209.000000        2209.000000  2209.000000
# mean         1.134903          5.824808           1.851064     9.959258
# std          0.525526          5.200300           1.395516     4.109811
# min          1.000000          1.000000           0.000000     1.000000
# 25%          1.000000          1.000000           1.000000     6.000000
# 50%          1.000000          4.000000           1.000000    11.000000
# 75%          1.000000          9.000000           2.000000    12.000000
# max          6.000000         18.000000           6.000000    17.000000
#
#        Daytime/evening attendance  Previous qualification  Nacionality  \
# count                 2209.000000             2209.000000  2209.000000
# mean                     0.909009                2.226799     1.237211
# std                      0.287662                3.680108     1.639871
# ...

# %%
df1["Unemployment rate"].mean()
# Out:
# 11.4336

# %%
df2["Unemployment rate"].mean()
# Out:
# 11.56395

# %%
df3["Unemployment rate"].mean()
# Out:
# 11.5735

# %%
df["Unemployment rate"].mean()
# Out:
# 11.56613924050633

# %%
sbn.countplot(x=df["Marital status"],hue=df["Target"])
# Out:
# <Axes: xlabel='Marital status', ylabel='count'>

# %%
sbn.countplot(x=df2["Marital status"],hue=df2["Target"])
# Out:
# <Axes: xlabel='Marital status', ylabel='count'>

# %%
import matplotlib.pyplot as plt

# %%
sbn.countplot(x=df["Gender"],hue=df["Target"])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sbn.countplot(x=df2["Gender"],hue=df2["Target"])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
d1=df1[df1["Target"]=="Dropout"]["GDP"]
d2=df2[df2["Target"]=="Dropout"]["GDP"]
d3=df3[df3["Target"]=="Dropout"]["GDP"]
d=df[df["Target"]=="Dropout"]["GDP"]
plt.boxplot([d1,d2,d3,d],labels=['sample1', 'sample2','sample3','total'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78cd1399f220>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x78cd1399f520>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78cd1399ef80>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x78cd1399fa60>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x78cd1399fd00>,
# ...
#  'means': []}

# %%
sbn.countplot(x=df["Scholarship holder"],hue=df["Target"])
# Out:
# <Axes: xlabel='Scholarship holder', ylabel='count'>

# %%
sbn.countplot(x=df1["Scholarship holder"],hue=df1["Target"])
# Out:
# <Axes: xlabel='Scholarship holder', ylabel='count'>

# %%
sbn.countplot(x=df2["Scholarship holder"],hue=df2["Target"])
# Out:
# <Axes: xlabel='Scholarship holder', ylabel='count'>

# %%
sbn.countplot(x=df3["Scholarship holder"],hue=df3["Target"])
# Out:
# <Axes: xlabel='Scholarship holder', ylabel='count'>

# %%
sbn.countplot(x=df["Target"],hue=df["Application mode"])
# Out:
# <Axes: xlabel='Target', ylabel='count'>

# %%
sbn.countplot(x=df2["Target"],hue=df2["Application mode"])
# Out:
# <Axes: xlabel='Target', ylabel='count'>

# %%
sbn.countplot(x=df["Target"],hue=df["Application order"])
# Out:
# <Axes: xlabel='Target', ylabel='count'>

# %%
sbn.countplot(x=df2["Target"],hue=df2["Application order"])
# Out:
# <Axes: xlabel='Target', ylabel='count'>

# %%
sbn.histplot(data=df["Age at enrollment"])
# Out:
# <Axes: xlabel='Age at enrollment', ylabel='Count'>

# %%
sbn.histplot(data=dfdrop["Age at enrollment"])
# Out:
# <Axes: xlabel='Age at enrollment', ylabel='Count'>

# %%
sbn.histplot(data=dfgrad["Age at enrollment"])
# Out:
# <Axes: xlabel='Age at enrollment', ylabel='Count'>
